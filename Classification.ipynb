# %%
from pyAudioAnalysis import audioTrainTest as aT
from pyAudioAnalysis import audioSegmentation
from pydub import AudioSegment
from pyAudioAnalysis import audioBasicIO as aIO
from pyAudioAnalysis import audioSegmentation as aS
# Out:
# In /home/mneskovic/anaconda3/envs/AudioAnalysis/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/mneskovic/anaconda3/envs/AudioAnalysis/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/mneskovic/anaconda3/envs/AudioAnalysis/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/mneskovic/anaconda3/envs/AudioAnalysis/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/mneskovic/anaconda3/envs/AudioAnalysis/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/mneskovic/anaconda3/envs/AudioAnalysis/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/mneskovic/anaconda3/envs/AudioAnalysis/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/mneskovic/anaconda3/envs/AudioAnalysis/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# /home/mneskovic/anaconda3/envs/AudioAnalysis/lib/python3.6/site-packages/pydub/utils.py:170: RuntimeWarning:
#
# Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work

# %%
# Out:
# [[1.42, 3.8000000000000003], [4.54, 6.0600000000000005], [9.66, 13.48], [13.540000000000001, 14.120000000000001], [14.38, 14.64], [17.14, 18.48], [19.82, 29.18], [29.78, 30.3], [31.42, 31.94], [33.3, 35.04], [35.160000000000004, 35.46], [35.86, 38.06], [38.78, 39.32]]
# [[0.0, 0.72], [2.38, 4.8], [6.140000000000001, 7.6000000000000005], [11.84, 14.22], [15.280000000000001, 16.94], [20.580000000000002, 22.82], [24.2, 26.04], [30.14, 32.08], [34.300000000000004, 36.04], [39.6, 42.18], [43.62, 45.36]]
# [[0.54, 1.68], [2.7800000000000002, 3.9], [7.1000000000000005, 8.38], [9.44, 10.52], [15.14, 17.28], [18.3, 19.88], [23.66, 25.66], [26.240000000000002, 27.64], [32.18, 33.86], [34.84, 36.160000000000004], [40.58, 42.2], [42.9, 44.26]]
# [[0.0, 2.84], [3.52, 5.18], [9.700000000000001, 11.66], [12.82, 14.58], [19.16, 21.38], [22.56, 24.46], [28.82, 30.740000000000002], [32.62, 34.22], [37.68, 39.36], [40.68, 42.26]]
# [[21.86, 55.4]]
# [[0.0, 1.98], [3.18, 4.44], [6.98, 8.82], [9.58, 11.06], [14.06, 15.540000000000001], [17.080000000000002, 18.46], [21.66, 23.64], [24.2, 25.48], [29.3, 31.42], [32.0, 33.24], [36.14, 38.06], [39.12, 40.5]]
# [[0.0, 0.92], [1.94, 3.46], [3.9, 4.92], [5.12, 5.82], [9.200000000000001, 10.200000000000001], [10.88, 11.8], [16.68, 18.18], [18.94, 19.7], [24.3, 26.14], [26.78, 27.96], [33.06, 34.42], [35.36, 36.52], [40.82, 41.88], [43.06, 43.980000000000004]]
# [[0.0, 0.84], [2.94, 4.42], [4.5600000000000005, 5.92], [10.120000000000001, 11.48], [12.5, 13.84], [17.42, 20.12], [20.32, 21.88], [26.92, 28.98], [30.12, 31.42], [36.1, 37.36], [38.62, 39.980000000000004]]

# %%
aT.extract_features_and_train(["data/exhale","data/inhale"], 1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm", "svmSMtemp", False)
# Out:
# Analyzing file 1 of 56: data/exhale/CollarMouthOut1.wav
# Analyzing file 2 of 56: data/exhale/CollarMouthOut2.wav
# Analyzing file 3 of 56: data/exhale/CollarMouthOut3.wav
# /home/mneskovic/School/CMSC715/pyAudioAnalysis/pyAudioAnalysis/audioBasicIO.py:99: WavFileWarning:
#
# Chunk (non-data) not understood, skipping it.
# Analyzing file 4 of 56: data/exhale/CollarMouthOut4.wav
# Analyzing file 5 of 56: data/exhale/CollarMouthOut5.wav
# Analyzing file 6 of 56: data/exhale/CollarMouthOut6.wav
# Analyzing file 7 of 56: data/exhale/CollarNoseOut1.wav
# Analyzing file 8 of 56: data/exhale/CollarNoseOut2.wav
# Analyzing file 9 of 56: data/exhale/CollarNoseOut3.wav
# Analyzing file 10 of 56: data/exhale/CollarNoseOut4.wav
# Analyzing file 11 of 56: data/exhale/CollarNoseOut5.wav
# Analyzing file 12 of 56: data/exhale/EarMouthOut1.wav
# Analyzing file 13 of 56: data/exhale/EarMouthOut2.wav
# Analyzing file 14 of 56: data/exhale/EarMouthOut3.wav
# Analyzing file 15 of 56: data/exhale/EarMouthOut4.wav
# Analyzing file 16 of 56: data/exhale/EarMouthOut5.wav
# Analyzing file 17 of 56: data/exhale/EarNoseOut1.wav
# Analyzing file 18 of 56: data/exhale/EarNoseOut2.wav
# Analyzing file 19 of 56: data/exhale/EarNoseOut3.wav
# Analyzing file 20 of 56: data/exhale/EarNoseOut4.wav
# Analyzing file 21 of 56: data/exhale/EarNoseOut5.wav
# Analyzing file 22 of 56: data/exhale/neck-mount_mouth_exhale_1.wav
# Analyzing file 23 of 56: data/exhale/neck-mount_mouth_exhale_2.wav
# Analyzing file 24 of 56: data/exhale/neck-mount_mouth_exhale_3.wav
# Analyzing file 25 of 56: data/exhale/neck-mount_mouth_exhale_4.wav
# Analyzing file 26 of 56: data/exhale/neck-mount_mouth_exhale_5.wav
# Analyzing file 27 of 56: data/exhale/neck-mount_mouth_exhale_6.wav
# Analyzing file 28 of 56: data/exhale/neck-mount_nose-exhale_1.wav
# Analyzing file 29 of 56: data/exhale/neck-mount_nose-exhale_2.wav
# Analyzing file 30 of 56: data/exhale/neck-mount_nose-exhale_3.wav
# Analyzing file 31 of 56: data/exhale/neck-mount_nose-exhale_4.wav
# Analyzing file 32 of 56: data/exhale/neck-mount_nose-exhale_5.wav
# Analyzing file 33 of 56: data/exhale/neck-mount_nose-exhale_6.wav
# Analyzing file 34 of 56: data/exhale/under-nose-up_mouth-exhale_1.wav
# Analyzing file 35 of 56: data/exhale/under-nose-up_mouth-exhale_2.wav
# Analyzing file 36 of 56: data/exhale/under-nose-up_mouth-exhale_3.wav
# Analyzing file 37 of 56: data/exhale/under-nose-up_mouth-exhale_4.wav
# Analyzing file 38 of 56: data/exhale/under-nose-up_mouth-exhale_5.wav
# Analyzing file 39 of 56: data/exhale/under-nose-up_mouth-exhale_6.wav
# Analyzing file 40 of 56: data/exhale/under-nose-up_mouth-exhale_7.wav
# Analyzing file 41 of 56: data/exhale/under-nose-up_nose-exhale_1.wav
# Analyzing file 42 of 56: data/exhale/under-nose-up_nose-exhale_2.wav
# Analyzing file 43 of 56: data/exhale/under-nose-up_nose-exhale_3.wav
# Analyzing file 44 of 56: data/exhale/under-nose-up_nose-exhale_4.wav
# Analyzing file 45 of 56: data/exhale/under-nose-up_nose-exhale_5.wav
# Analyzing file 46 of 56: data/exhale/upper-back_mouth-exhale_1.wav
# Analyzing file 47 of 56: data/exhale/upper-back_mouth-exhale_2.wav
# Analyzing file 48 of 56: data/exhale/upper-back_mouth-exhale_3.wav
# Analyzing file 49 of 56: data/exhale/upper-back_mouth-exhale_4.wav
# Analyzing file 50 of 56: data/exhale/upper-back_mouth-exhale_5.wav
# Analyzing file 51 of 56: data/exhale/upper-back_mouth-exhale_6.wav
# Analyzing file 52 of 56: data/exhale/upper-back_nose-exhale_1.wav
# Analyzing file 53 of 56: data/exhale/upper-back_nose-exhale_2.wav
# Analyzing file 54 of 56: data/exhale/upper-back_nose-exhale_3.wav
# Analyzing file 55 of 56: data/exhale/upper-back_nose-exhale_4.wav
# Analyzing file 56 of 56: data/exhale/upper-back_nose-exhale_5.wav
# Feature extraction complexity ratio: 10.8 x realtime
# Analyzing file 1 of 57: data/inhale/CollarMouthIn1.wav
# Analyzing file 2 of 57: data/inhale/CollarMouthIn2.wav
# Analyzing file 3 of 57: data/inhale/CollarMouthIn3.wav
# Analyzing file 4 of 57: data/inhale/CollarMouthIn4.wav
# Analyzing file 5 of 57: data/inhale/CollarMouthIn5.wav
# Analyzing file 6 of 57: data/inhale/CollarMouthIn6.wav
# Analyzing file 7 of 57: data/inhale/CollarNoseIn1.wav
# Analyzing file 8 of 57: data/inhale/CollarNoseIn2.wav
# Analyzing file 9 of 57: data/inhale/CollarNoseIn3.wav
# Analyzing file 10 of 57: data/inhale/CollarNoseIn4.wav
# Analyzing file 11 of 57: data/inhale/CollarNoseIn5.wav
# Analyzing file 12 of 57: data/inhale/EarMouthIn1.wav
# Analyzing file 13 of 57: data/inhale/EarMouthIn2.wav
# Analyzing file 14 of 57: data/inhale/EarMouthIn3.wav
# Analyzing file 15 of 57: data/inhale/EarMouthIn4.wav
# Analyzing file 16 of 57: data/inhale/EarMouthIn5.wav
# Analyzing file 17 of 57: data/inhale/EarNoseIn1.wav
# Analyzing file 18 of 57: data/inhale/EarNoseIn2.wav
# Analyzing file 19 of 57: data/inhale/EarNoseIn3.wav
# Analyzing file 20 of 57: data/inhale/EarNoseIn4.wav
# Analyzing file 21 of 57: data/inhale/EarNoseIn5.wav
# Analyzing file 22 of 57: data/inhale/neck-mount_mouth-inhale_1.wav
# Analyzing file 23 of 57: data/inhale/neck-mount_mouth-inhale_2.wav
# Analyzing file 24 of 57: data/inhale/neck-mount_mouth-inhale_3.wav
# Analyzing file 25 of 57: data/inhale/neck-mount_mouth-inhale_4.wav
# Analyzing file 26 of 57: data/inhale/neck-mount_mouth-inhale_5.wav
# Analyzing file 27 of 57: data/inhale/neck-mount_mouth-inhale_6.wav
# Analyzing file 28 of 57: data/inhale/neck-mount_nose-inhale_1.wav
# Analyzing file 29 of 57: data/inhale/neck-mount_nose-inhale_2.wav
# Analyzing file 30 of 57: data/inhale/neck-mount_nose-inhale_3.wav
# Analyzing file 31 of 57: data/inhale/neck-mount_nose-inhale_4.wav
# Analyzing file 32 of 57: data/inhale/neck-mount_nose-inhale_5.wav
# Analyzing file 33 of 57: data/inhale/neck-mount_nose-inhale_6.wav
# Analyzing file 34 of 57: data/inhale/under-nose-up_mouth-inhale_1.wav
# Analyzing file 35 of 57: data/inhale/under-nose-up_mouth-inhale_2.wav
# Analyzing file 36 of 57: data/inhale/under-nose-up_mouth-inhale_3.wav
# Analyzing file 37 of 57: data/inhale/under-nose-up_mouth-inhale_4.wav
# Analyzing file 38 of 57: data/inhale/under-nose-up_mouth-inhale_5.wav
# Analyzing file 39 of 57: data/inhale/under-nose-up_mouth-inhale_6.wav
# Analyzing file 40 of 57: data/inhale/under-nose-up_mouth-inhale_7.wav
# Analyzing file 41 of 57: data/inhale/under-nose-up_nose-inhale_1.wav
# Analyzing file 42 of 57: data/inhale/under-nose-up_nose-inhale_2.wav
# Analyzing file 43 of 57: data/inhale/under-nose-up_nose-inhale_3.wav
# Analyzing file 44 of 57: data/inhale/under-nose-up_nose-inhale_4.wav
# Analyzing file 45 of 57: data/inhale/under-nose-up_nose-inhale_5.wav
# Analyzing file 46 of 57: data/inhale/under-nose-up_nose-inhale_6.wav
# Analyzing file 47 of 57: data/inhale/upper-back_mouth-inhale_1.wav
# Analyzing file 48 of 57: data/inhale/upper-back_mouth-inhale_2.wav
# Analyzing file 49 of 57: data/inhale/upper-back_mouth-inhale_3.wav
# Analyzing file 50 of 57: data/inhale/upper-back_mouth-inhale_4.wav
# Analyzing file 51 of 57: data/inhale/upper-back_mouth-inhale_5.wav
# Analyzing file 52 of 57: data/inhale/upper-back_mouth-inhale_6.wav
# Analyzing file 53 of 57: data/inhale/upper-back_nose-inhale_1.wav
# Analyzing file 54 of 57: data/inhale/upper-back_nose-inhale_2.wav
# Analyzing file 55 of 57: data/inhale/upper-back_nose-inhale_3.wav
# Analyzing file 56 of 57: data/inhale/upper-back_nose-inhale_4.wav
# Analyzing file 57 of 57: data/inhale/upper-back_nose-inhale_5.wav
# Feature extraction complexity ratio: 10.1 x realtime
# Param = 0.00100 - classifier Evaluation Experiment 1 of 89
# Param = 0.00100 - classifier Evaluation Experiment 2 of 89
# Param = 0.00100 - classifier Evaluation Experiment 3 of 89
# Param = 0.00100 - classifier Evaluation Experiment 4 of 89
# Param = 0.00100 - classifier Evaluation Experiment 5 of 89
# Param = 0.00100 - classifier Evaluation Experiment 6 of 89
# Param = 0.00100 - classifier Evaluation Experiment 7 of 89
# Param = 0.00100 - classifier Evaluation Experiment 8 of 89
# Param = 0.00100 - classifier Evaluation Experiment 9 of 89
# Param = 0.00100 - classifier Evaluation Experiment 10 of 89
# Param = 0.00100 - classifier Evaluation Experiment 11 of 89
# Param = 0.00100 - classifier Evaluation Experiment 12 of 89
# Param = 0.00100 - classifier Evaluation Experiment 13 of 89
# Param = 0.00100 - classifier Evaluation Experiment 14 of 89
# Param = 0.00100 - classifier Evaluation Experiment 15 of 89
# Param = 0.00100 - classifier Evaluation Experiment 16 of 89
# Param = 0.00100 - classifier Evaluation Experiment 17 of 89
# Param = 0.00100 - classifier Evaluation Experiment 18 of 89
# Param = 0.00100 - classifier Evaluation Experiment 19 of 89
# Param = 0.00100 - classifier Evaluation Experiment 20 of 89
# Param = 0.00100 - classifier Evaluation Experiment 21 of 89
# Param = 0.00100 - classifier Evaluation Experiment 22 of 89
# Param = 0.00100 - classifier Evaluation Experiment 23 of 89
# Param = 0.00100 - classifier Evaluation Experiment 24 of 89
# Param = 0.00100 - classifier Evaluation Experiment 25 of 89
# Param = 0.00100 - classifier Evaluation Experiment 26 of 89
# Param = 0.00100 - classifier Evaluation Experiment 27 of 89
# Param = 0.00100 - classifier Evaluation Experiment 28 of 89
# Param = 0.00100 - classifier Evaluation Experiment 29 of 89
# Param = 0.00100 - classifier Evaluation Experiment 30 of 89
# Param = 0.00100 - classifier Evaluation Experiment 31 of 89
# Param = 0.00100 - classifier Evaluation Experiment 32 of 89
# Param = 0.00100 - classifier Evaluation Experiment 33 of 89
# Param = 0.00100 - classifier Evaluation Experiment 34 of 89
# Param = 0.00100 - classifier Evaluation Experiment 35 of 89
# Param = 0.00100 - classifier Evaluation Experiment 36 of 89
# Param = 0.00100 - classifier Evaluation Experiment 37 of 89
# Param = 0.00100 - classifier Evaluation Experiment 38 of 89
# Param = 0.00100 - classifier Evaluation Experiment 39 of 89
# Param = 0.00100 - classifier Evaluation Experiment 40 of 89
# Param = 0.00100 - classifier Evaluation Experiment 41 of 89
# Param = 0.00100 - classifier Evaluation Experiment 42 of 89
# Param = 0.00100 - classifier Evaluation Experiment 43 of 89
# Param = 0.00100 - classifier Evaluation Experiment 44 of 89
# Param = 0.00100 - classifier Evaluation Experiment 45 of 89
# Param = 0.00100 - classifier Evaluation Experiment 46 of 89
# Param = 0.00100 - classifier Evaluation Experiment 47 of 89
# Param = 0.00100 - classifier Evaluation Experiment 48 of 89
# Param = 0.00100 - classifier Evaluation Experiment 49 of 89
# Param = 0.00100 - classifier Evaluation Experiment 50 of 89
# Param = 0.00100 - classifier Evaluation Experiment 51 of 89
# Param = 0.00100 - classifier Evaluation Experiment 52 of 89
# Param = 0.00100 - classifier Evaluation Experiment 53 of 89
# Param = 0.00100 - classifier Evaluation Experiment 54 of 89
# Param = 0.00100 - classifier Evaluation Experiment 55 of 89
# Param = 0.00100 - classifier Evaluation Experiment 56 of 89
# Param = 0.00100 - classifier Evaluation Experiment 57 of 89
# Param = 0.00100 - classifier Evaluation Experiment 58 of 89
# Param = 0.00100 - classifier Evaluation Experiment 59 of 89
# Param = 0.00100 - classifier Evaluation Experiment 60 of 89
# Param = 0.00100 - classifier Evaluation Experiment 61 of 89
# Param = 0.00100 - classifier Evaluation Experiment 62 of 89
# Param = 0.00100 - classifier Evaluation Experiment 63 of 89
# Param = 0.00100 - classifier Evaluation Experiment 64 of 89
# Param = 0.00100 - classifier Evaluation Experiment 65 of 89
# Param = 0.00100 - classifier Evaluation Experiment 66 of 89
# Param = 0.00100 - classifier Evaluation Experiment 67 of 89
# Param = 0.00100 - classifier Evaluation Experiment 68 of 89
# Param = 0.00100 - classifier Evaluation Experiment 69 of 89
# Param = 0.00100 - classifier Evaluation Experiment 70 of 89
# Param = 0.00100 - classifier Evaluation Experiment 71 of 89
# Param = 0.00100 - classifier Evaluation Experiment 72 of 89
# Param = 0.00100 - classifier Evaluation Experiment 73 of 89
# Param = 0.00100 - classifier Evaluation Experiment 74 of 89
# Param = 0.00100 - classifier Evaluation Experiment 75 of 89
# Param = 0.00100 - classifier Evaluation Experiment 76 of 89
# Param = 0.00100 - classifier Evaluation Experiment 77 of 89
# Param = 0.00100 - classifier Evaluation Experiment 78 of 89
# Param = 0.00100 - classifier Evaluation Experiment 79 of 89
# Param = 0.00100 - classifier Evaluation Experiment 80 of 89
# Param = 0.00100 - classifier Evaluation Experiment 81 of 89
# Param = 0.00100 - classifier Evaluation Experiment 82 of 89
# Param = 0.00100 - classifier Evaluation Experiment 83 of 89
# Param = 0.00100 - classifier Evaluation Experiment 84 of 89
# Param = 0.00100 - classifier Evaluation Experiment 85 of 89
# Param = 0.00100 - classifier Evaluation Experiment 86 of 89
# Param = 0.00100 - classifier Evaluation Experiment 87 of 89
# Param = 0.00100 - classifier Evaluation Experiment 88 of 89
# Param = 0.00100 - classifier Evaluation Experiment 89 of 89
# Param = 0.01000 - classifier Evaluation Experiment 1 of 89
# Param = 0.01000 - classifier Evaluation Experiment 2 of 89
# Param = 0.01000 - classifier Evaluation Experiment 3 of 89
# Param = 0.01000 - classifier Evaluation Experiment 4 of 89
# Param = 0.01000 - classifier Evaluation Experiment 5 of 89
# Param = 0.01000 - classifier Evaluation Experiment 6 of 89
# Param = 0.01000 - classifier Evaluation Experiment 7 of 89
# Param = 0.01000 - classifier Evaluation Experiment 8 of 89
# Param = 0.01000 - classifier Evaluation Experiment 9 of 89
# Param = 0.01000 - classifier Evaluation Experiment 10 of 89
# Param = 0.01000 - classifier Evaluation Experiment 11 of 89
# Param = 0.01000 - classifier Evaluation Experiment 12 of 89
# Param = 0.01000 - classifier Evaluation Experiment 13 of 89
# Param = 0.01000 - classifier Evaluation Experiment 14 of 89
# Param = 0.01000 - classifier Evaluation Experiment 15 of 89
# Param = 0.01000 - classifier Evaluation Experiment 16 of 89
# Param = 0.01000 - classifier Evaluation Experiment 17 of 89
# Param = 0.01000 - classifier Evaluation Experiment 18 of 89
# Param = 0.01000 - classifier Evaluation Experiment 19 of 89
# Param = 0.01000 - classifier Evaluation Experiment 20 of 89
# Param = 0.01000 - classifier Evaluation Experiment 21 of 89
# Param = 0.01000 - classifier Evaluation Experiment 22 of 89
# Param = 0.01000 - classifier Evaluation Experiment 23 of 89
# Param = 0.01000 - classifier Evaluation Experiment 24 of 89
# Param = 0.01000 - classifier Evaluation Experiment 25 of 89
# Param = 0.01000 - classifier Evaluation Experiment 26 of 89
# Param = 0.01000 - classifier Evaluation Experiment 27 of 89
# Param = 0.01000 - classifier Evaluation Experiment 28 of 89
# Param = 0.01000 - classifier Evaluation Experiment 29 of 89
# Param = 0.01000 - classifier Evaluation Experiment 30 of 89
# Param = 0.01000 - classifier Evaluation Experiment 31 of 89
# Param = 0.01000 - classifier Evaluation Experiment 32 of 89
# Param = 0.01000 - classifier Evaluation Experiment 33 of 89
# Param = 0.01000 - classifier Evaluation Experiment 34 of 89
# Param = 0.01000 - classifier Evaluation Experiment 35 of 89
# Param = 0.01000 - classifier Evaluation Experiment 36 of 89
# Param = 0.01000 - classifier Evaluation Experiment 37 of 89
# Param = 0.01000 - classifier Evaluation Experiment 38 of 89
# Param = 0.01000 - classifier Evaluation Experiment 39 of 89
# Param = 0.01000 - classifier Evaluation Experiment 40 of 89
# Param = 0.01000 - classifier Evaluation Experiment 41 of 89
# Param = 0.01000 - classifier Evaluation Experiment 42 of 89
# Param = 0.01000 - classifier Evaluation Experiment 43 of 89
# Param = 0.01000 - classifier Evaluation Experiment 44 of 89
# Param = 0.01000 - classifier Evaluation Experiment 45 of 89
# Param = 0.01000 - classifier Evaluation Experiment 46 of 89
# Param = 0.01000 - classifier Evaluation Experiment 47 of 89
# Param = 0.01000 - classifier Evaluation Experiment 48 of 89
# Param = 0.01000 - classifier Evaluation Experiment 49 of 89
# Param = 0.01000 - classifier Evaluation Experiment 50 of 89
# Param = 0.01000 - classifier Evaluation Experiment 51 of 89
# Param = 0.01000 - classifier Evaluation Experiment 52 of 89
# Param = 0.01000 - classifier Evaluation Experiment 53 of 89
# Param = 0.01000 - classifier Evaluation Experiment 54 of 89
# Param = 0.01000 - classifier Evaluation Experiment 55 of 89
# Param = 0.01000 - classifier Evaluation Experiment 56 of 89
# Param = 0.01000 - classifier Evaluation Experiment 57 of 89
# Param = 0.01000 - classifier Evaluation Experiment 58 of 89
# Param = 0.01000 - classifier Evaluation Experiment 59 of 89
# Param = 0.01000 - classifier Evaluation Experiment 60 of 89
# Param = 0.01000 - classifier Evaluation Experiment 61 of 89
# Param = 0.01000 - classifier Evaluation Experiment 62 of 89
# Param = 0.01000 - classifier Evaluation Experiment 63 of 89
# Param = 0.01000 - classifier Evaluation Experiment 64 of 89
# Param = 0.01000 - classifier Evaluation Experiment 65 of 89
# Param = 0.01000 - classifier Evaluation Experiment 66 of 89
# Param = 0.01000 - classifier Evaluation Experiment 67 of 89
# Param = 0.01000 - classifier Evaluation Experiment 68 of 89
# Param = 0.01000 - classifier Evaluation Experiment 69 of 89
# Param = 0.01000 - classifier Evaluation Experiment 70 of 89
# Param = 0.01000 - classifier Evaluation Experiment 71 of 89
# Param = 0.01000 - classifier Evaluation Experiment 72 of 89
# Param = 0.01000 - classifier Evaluation Experiment 73 of 89
# Param = 0.01000 - classifier Evaluation Experiment 74 of 89
# Param = 0.01000 - classifier Evaluation Experiment 75 of 89
# Param = 0.01000 - classifier Evaluation Experiment 76 of 89
# Param = 0.01000 - classifier Evaluation Experiment 77 of 89
# Param = 0.01000 - classifier Evaluation Experiment 78 of 89
# Param = 0.01000 - classifier Evaluation Experiment 79 of 89
# Param = 0.01000 - classifier Evaluation Experiment 80 of 89
# Param = 0.01000 - classifier Evaluation Experiment 81 of 89
# Param = 0.01000 - classifier Evaluation Experiment 82 of 89
# Param = 0.01000 - classifier Evaluation Experiment 83 of 89
# Param = 0.01000 - classifier Evaluation Experiment 84 of 89
# Param = 0.01000 - classifier Evaluation Experiment 85 of 89
# Param = 0.01000 - classifier Evaluation Experiment 86 of 89
# Param = 0.01000 - classifier Evaluation Experiment 87 of 89
# Param = 0.01000 - classifier Evaluation Experiment 88 of 89
# Param = 0.01000 - classifier Evaluation Experiment 89 of 89
# Param = 0.50000 - classifier Evaluation Experiment 1 of 89
# Param = 0.50000 - classifier Evaluation Experiment 2 of 89
# Param = 0.50000 - classifier Evaluation Experiment 3 of 89
# Param = 0.50000 - classifier Evaluation Experiment 4 of 89
# Param = 0.50000 - classifier Evaluation Experiment 5 of 89
# Param = 0.50000 - classifier Evaluation Experiment 6 of 89
# Param = 0.50000 - classifier Evaluation Experiment 7 of 89
# Param = 0.50000 - classifier Evaluation Experiment 8 of 89
# Param = 0.50000 - classifier Evaluation Experiment 9 of 89
# Param = 0.50000 - classifier Evaluation Experiment 10 of 89
# Param = 0.50000 - classifier Evaluation Experiment 11 of 89
# Param = 0.50000 - classifier Evaluation Experiment 12 of 89
# Param = 0.50000 - classifier Evaluation Experiment 13 of 89
# Param = 0.50000 - classifier Evaluation Experiment 14 of 89
# Param = 0.50000 - classifier Evaluation Experiment 15 of 89
# Param = 0.50000 - classifier Evaluation Experiment 16 of 89
# Param = 0.50000 - classifier Evaluation Experiment 17 of 89
# Param = 0.50000 - classifier Evaluation Experiment 18 of 89
# Param = 0.50000 - classifier Evaluation Experiment 19 of 89
# Param = 0.50000 - classifier Evaluation Experiment 20 of 89
# Param = 0.50000 - classifier Evaluation Experiment 21 of 89
# Param = 0.50000 - classifier Evaluation Experiment 22 of 89
# Param = 0.50000 - classifier Evaluation Experiment 23 of 89
# Param = 0.50000 - classifier Evaluation Experiment 24 of 89
# Param = 0.50000 - classifier Evaluation Experiment 25 of 89
# Param = 0.50000 - classifier Evaluation Experiment 26 of 89
# Param = 0.50000 - classifier Evaluation Experiment 27 of 89
# Param = 0.50000 - classifier Evaluation Experiment 28 of 89
# Param = 0.50000 - classifier Evaluation Experiment 29 of 89
# Param = 0.50000 - classifier Evaluation Experiment 30 of 89
# Param = 0.50000 - classifier Evaluation Experiment 31 of 89
# Param = 0.50000 - classifier Evaluation Experiment 32 of 89
# Param = 0.50000 - classifier Evaluation Experiment 33 of 89
# Param = 0.50000 - classifier Evaluation Experiment 34 of 89
# Param = 0.50000 - classifier Evaluation Experiment 35 of 89
# Param = 0.50000 - classifier Evaluation Experiment 36 of 89
# Param = 0.50000 - classifier Evaluation Experiment 37 of 89
# Param = 0.50000 - classifier Evaluation Experiment 38 of 89
# Param = 0.50000 - classifier Evaluation Experiment 39 of 89
# Param = 0.50000 - classifier Evaluation Experiment 40 of 89
# Param = 0.50000 - classifier Evaluation Experiment 41 of 89
# Param = 0.50000 - classifier Evaluation Experiment 42 of 89
# Param = 0.50000 - classifier Evaluation Experiment 43 of 89
# Param = 0.50000 - classifier Evaluation Experiment 44 of 89
# Param = 0.50000 - classifier Evaluation Experiment 45 of 89
# Param = 0.50000 - classifier Evaluation Experiment 46 of 89
# Param = 0.50000 - classifier Evaluation Experiment 47 of 89
# Param = 0.50000 - classifier Evaluation Experiment 48 of 89
# Param = 0.50000 - classifier Evaluation Experiment 49 of 89
# Param = 0.50000 - classifier Evaluation Experiment 50 of 89
# Param = 0.50000 - classifier Evaluation Experiment 51 of 89
# Param = 0.50000 - classifier Evaluation Experiment 52 of 89
# Param = 0.50000 - classifier Evaluation Experiment 53 of 89
# Param = 0.50000 - classifier Evaluation Experiment 54 of 89
# Param = 0.50000 - classifier Evaluation Experiment 55 of 89
# Param = 0.50000 - classifier Evaluation Experiment 56 of 89
# Param = 0.50000 - classifier Evaluation Experiment 57 of 89
# Param = 0.50000 - classifier Evaluation Experiment 58 of 89
# Param = 0.50000 - classifier Evaluation Experiment 59 of 89
# Param = 0.50000 - classifier Evaluation Experiment 60 of 89
# Param = 0.50000 - classifier Evaluation Experiment 61 of 89
# Param = 0.50000 - classifier Evaluation Experiment 62 of 89
# Param = 0.50000 - classifier Evaluation Experiment 63 of 89
# Param = 0.50000 - classifier Evaluation Experiment 64 of 89
# Param = 0.50000 - classifier Evaluation Experiment 65 of 89
# Param = 0.50000 - classifier Evaluation Experiment 66 of 89
# Param = 0.50000 - classifier Evaluation Experiment 67 of 89
# Param = 0.50000 - classifier Evaluation Experiment 68 of 89
# Param = 0.50000 - classifier Evaluation Experiment 69 of 89
# Param = 0.50000 - classifier Evaluation Experiment 70 of 89
# Param = 0.50000 - classifier Evaluation Experiment 71 of 89
# Param = 0.50000 - classifier Evaluation Experiment 72 of 89
# Param = 0.50000 - classifier Evaluation Experiment 73 of 89
# Param = 0.50000 - classifier Evaluation Experiment 74 of 89
# Param = 0.50000 - classifier Evaluation Experiment 75 of 89
# Param = 0.50000 - classifier Evaluation Experiment 76 of 89
# Param = 0.50000 - classifier Evaluation Experiment 77 of 89
# Param = 0.50000 - classifier Evaluation Experiment 78 of 89
# Param = 0.50000 - classifier Evaluation Experiment 79 of 89
# Param = 0.50000 - classifier Evaluation Experiment 80 of 89
# Param = 0.50000 - classifier Evaluation Experiment 81 of 89
# Param = 0.50000 - classifier Evaluation Experiment 82 of 89
# Param = 0.50000 - classifier Evaluation Experiment 83 of 89
# Param = 0.50000 - classifier Evaluation Experiment 84 of 89
# Param = 0.50000 - classifier Evaluation Experiment 85 of 89
# Param = 0.50000 - classifier Evaluation Experiment 86 of 89
# Param = 0.50000 - classifier Evaluation Experiment 87 of 89
# Param = 0.50000 - classifier Evaluation Experiment 88 of 89
# Param = 0.50000 - classifier Evaluation Experiment 89 of 89
# Param = 1.00000 - classifier Evaluation Experiment 1 of 89
# Param = 1.00000 - classifier Evaluation Experiment 2 of 89
# Param = 1.00000 - classifier Evaluation Experiment 3 of 89
# Param = 1.00000 - classifier Evaluation Experiment 4 of 89
# Param = 1.00000 - classifier Evaluation Experiment 5 of 89
# Param = 1.00000 - classifier Evaluation Experiment 6 of 89
# Param = 1.00000 - classifier Evaluation Experiment 7 of 89
# Param = 1.00000 - classifier Evaluation Experiment 8 of 89
# Param = 1.00000 - classifier Evaluation Experiment 9 of 89
# Param = 1.00000 - classifier Evaluation Experiment 10 of 89
# Param = 1.00000 - classifier Evaluation Experiment 11 of 89
# Param = 1.00000 - classifier Evaluation Experiment 12 of 89
# Param = 1.00000 - classifier Evaluation Experiment 13 of 89
# Param = 1.00000 - classifier Evaluation Experiment 14 of 89
# Param = 1.00000 - classifier Evaluation Experiment 15 of 89
# Param = 1.00000 - classifier Evaluation Experiment 16 of 89
# Param = 1.00000 - classifier Evaluation Experiment 17 of 89
# Param = 1.00000 - classifier Evaluation Experiment 18 of 89
# Param = 1.00000 - classifier Evaluation Experiment 19 of 89
# Param = 1.00000 - classifier Evaluation Experiment 20 of 89
# Param = 1.00000 - classifier Evaluation Experiment 21 of 89
# Param = 1.00000 - classifier Evaluation Experiment 22 of 89
# Param = 1.00000 - classifier Evaluation Experiment 23 of 89
# Param = 1.00000 - classifier Evaluation Experiment 24 of 89
# Param = 1.00000 - classifier Evaluation Experiment 25 of 89
# Param = 1.00000 - classifier Evaluation Experiment 26 of 89
# Param = 1.00000 - classifier Evaluation Experiment 27 of 89
# Param = 1.00000 - classifier Evaluation Experiment 28 of 89
# Param = 1.00000 - classifier Evaluation Experiment 29 of 89
# Param = 1.00000 - classifier Evaluation Experiment 30 of 89
# Param = 1.00000 - classifier Evaluation Experiment 31 of 89
# Param = 1.00000 - classifier Evaluation Experiment 32 of 89
# Param = 1.00000 - classifier Evaluation Experiment 33 of 89
# Param = 1.00000 - classifier Evaluation Experiment 34 of 89
# Param = 1.00000 - classifier Evaluation Experiment 35 of 89
# Param = 1.00000 - classifier Evaluation Experiment 36 of 89
# Param = 1.00000 - classifier Evaluation Experiment 37 of 89
# Param = 1.00000 - classifier Evaluation Experiment 38 of 89
# Param = 1.00000 - classifier Evaluation Experiment 39 of 89
# Param = 1.00000 - classifier Evaluation Experiment 40 of 89
# Param = 1.00000 - classifier Evaluation Experiment 41 of 89
# Param = 1.00000 - classifier Evaluation Experiment 42 of 89
# Param = 1.00000 - classifier Evaluation Experiment 43 of 89
# Param = 1.00000 - classifier Evaluation Experiment 44 of 89
# Param = 1.00000 - classifier Evaluation Experiment 45 of 89
# Param = 1.00000 - classifier Evaluation Experiment 46 of 89
# Param = 1.00000 - classifier Evaluation Experiment 47 of 89
# Param = 1.00000 - classifier Evaluation Experiment 48 of 89
# Param = 1.00000 - classifier Evaluation Experiment 49 of 89
# Param = 1.00000 - classifier Evaluation Experiment 50 of 89
# Param = 1.00000 - classifier Evaluation Experiment 51 of 89
# Param = 1.00000 - classifier Evaluation Experiment 52 of 89
# Param = 1.00000 - classifier Evaluation Experiment 53 of 89
# Param = 1.00000 - classifier Evaluation Experiment 54 of 89
# Param = 1.00000 - classifier Evaluation Experiment 55 of 89
# Param = 1.00000 - classifier Evaluation Experiment 56 of 89
# Param = 1.00000 - classifier Evaluation Experiment 57 of 89
# Param = 1.00000 - classifier Evaluation Experiment 58 of 89
# Param = 1.00000 - classifier Evaluation Experiment 59 of 89
# Param = 1.00000 - classifier Evaluation Experiment 60 of 89
# Param = 1.00000 - classifier Evaluation Experiment 61 of 89
# Param = 1.00000 - classifier Evaluation Experiment 62 of 89
# Param = 1.00000 - classifier Evaluation Experiment 63 of 89
# Param = 1.00000 - classifier Evaluation Experiment 64 of 89
# Param = 1.00000 - classifier Evaluation Experiment 65 of 89
# Param = 1.00000 - classifier Evaluation Experiment 66 of 89
# Param = 1.00000 - classifier Evaluation Experiment 67 of 89
# Param = 1.00000 - classifier Evaluation Experiment 68 of 89
# Param = 1.00000 - classifier Evaluation Experiment 69 of 89
# Param = 1.00000 - classifier Evaluation Experiment 70 of 89
# Param = 1.00000 - classifier Evaluation Experiment 71 of 89
# Param = 1.00000 - classifier Evaluation Experiment 72 of 89
# Param = 1.00000 - classifier Evaluation Experiment 73 of 89
# Param = 1.00000 - classifier Evaluation Experiment 74 of 89
# Param = 1.00000 - classifier Evaluation Experiment 75 of 89
# Param = 1.00000 - classifier Evaluation Experiment 76 of 89
# Param = 1.00000 - classifier Evaluation Experiment 77 of 89
# Param = 1.00000 - classifier Evaluation Experiment 78 of 89
# Param = 1.00000 - classifier Evaluation Experiment 79 of 89
# Param = 1.00000 - classifier Evaluation Experiment 80 of 89
# Param = 1.00000 - classifier Evaluation Experiment 81 of 89
# Param = 1.00000 - classifier Evaluation Experiment 82 of 89
# Param = 1.00000 - classifier Evaluation Experiment 83 of 89
# Param = 1.00000 - classifier Evaluation Experiment 84 of 89
# Param = 1.00000 - classifier Evaluation Experiment 85 of 89
# Param = 1.00000 - classifier Evaluation Experiment 86 of 89
# Param = 1.00000 - classifier Evaluation Experiment 87 of 89
# Param = 1.00000 - classifier Evaluation Experiment 88 of 89
# Param = 1.00000 - classifier Evaluation Experiment 89 of 89
# Param = 5.00000 - classifier Evaluation Experiment 1 of 89
# Param = 5.00000 - classifier Evaluation Experiment 2 of 89
# Param = 5.00000 - classifier Evaluation Experiment 3 of 89
# Param = 5.00000 - classifier Evaluation Experiment 4 of 89
# Param = 5.00000 - classifier Evaluation Experiment 5 of 89
# Param = 5.00000 - classifier Evaluation Experiment 6 of 89
# Param = 5.00000 - classifier Evaluation Experiment 7 of 89
# Param = 5.00000 - classifier Evaluation Experiment 8 of 89
# Param = 5.00000 - classifier Evaluation Experiment 9 of 89
# Param = 5.00000 - classifier Evaluation Experiment 10 of 89
# Param = 5.00000 - classifier Evaluation Experiment 11 of 89
# Param = 5.00000 - classifier Evaluation Experiment 12 of 89
# Param = 5.00000 - classifier Evaluation Experiment 13 of 89
# Param = 5.00000 - classifier Evaluation Experiment 14 of 89
# Param = 5.00000 - classifier Evaluation Experiment 15 of 89
# Param = 5.00000 - classifier Evaluation Experiment 16 of 89
# Param = 5.00000 - classifier Evaluation Experiment 17 of 89
# Param = 5.00000 - classifier Evaluation Experiment 18 of 89
# Param = 5.00000 - classifier Evaluation Experiment 19 of 89
# Param = 5.00000 - classifier Evaluation Experiment 20 of 89
# Param = 5.00000 - classifier Evaluation Experiment 21 of 89
# Param = 5.00000 - classifier Evaluation Experiment 22 of 89
# Param = 5.00000 - classifier Evaluation Experiment 23 of 89
# Param = 5.00000 - classifier Evaluation Experiment 24 of 89
# Param = 5.00000 - classifier Evaluation Experiment 25 of 89
# Param = 5.00000 - classifier Evaluation Experiment 26 of 89
# Param = 5.00000 - classifier Evaluation Experiment 27 of 89
# Param = 5.00000 - classifier Evaluation Experiment 28 of 89
# Param = 5.00000 - classifier Evaluation Experiment 29 of 89
# Param = 5.00000 - classifier Evaluation Experiment 30 of 89
# Param = 5.00000 - classifier Evaluation Experiment 31 of 89
# Param = 5.00000 - classifier Evaluation Experiment 32 of 89
# Param = 5.00000 - classifier Evaluation Experiment 33 of 89
# Param = 5.00000 - classifier Evaluation Experiment 34 of 89
# Param = 5.00000 - classifier Evaluation Experiment 35 of 89
# Param = 5.00000 - classifier Evaluation Experiment 36 of 89
# Param = 5.00000 - classifier Evaluation Experiment 37 of 89
# Param = 5.00000 - classifier Evaluation Experiment 38 of 89
# Param = 5.00000 - classifier Evaluation Experiment 39 of 89
# Param = 5.00000 - classifier Evaluation Experiment 40 of 89
# Param = 5.00000 - classifier Evaluation Experiment 41 of 89
# Param = 5.00000 - classifier Evaluation Experiment 42 of 89
# Param = 5.00000 - classifier Evaluation Experiment 43 of 89
# Param = 5.00000 - classifier Evaluation Experiment 44 of 89
# Param = 5.00000 - classifier Evaluation Experiment 45 of 89
# Param = 5.00000 - classifier Evaluation Experiment 46 of 89
# Param = 5.00000 - classifier Evaluation Experiment 47 of 89
# Param = 5.00000 - classifier Evaluation Experiment 48 of 89
# Param = 5.00000 - classifier Evaluation Experiment 49 of 89
# Param = 5.00000 - classifier Evaluation Experiment 50 of 89
# Param = 5.00000 - classifier Evaluation Experiment 51 of 89
# Param = 5.00000 - classifier Evaluation Experiment 52 of 89
# Param = 5.00000 - classifier Evaluation Experiment 53 of 89
# Param = 5.00000 - classifier Evaluation Experiment 54 of 89
# Param = 5.00000 - classifier Evaluation Experiment 55 of 89
# Param = 5.00000 - classifier Evaluation Experiment 56 of 89
# Param = 5.00000 - classifier Evaluation Experiment 57 of 89
# Param = 5.00000 - classifier Evaluation Experiment 58 of 89
# Param = 5.00000 - classifier Evaluation Experiment 59 of 89
# Param = 5.00000 - classifier Evaluation Experiment 60 of 89
# Param = 5.00000 - classifier Evaluation Experiment 61 of 89
# Param = 5.00000 - classifier Evaluation Experiment 62 of 89
# Param = 5.00000 - classifier Evaluation Experiment 63 of 89
# Param = 5.00000 - classifier Evaluation Experiment 64 of 89
# Param = 5.00000 - classifier Evaluation Experiment 65 of 89
# Param = 5.00000 - classifier Evaluation Experiment 66 of 89
# Param = 5.00000 - classifier Evaluation Experiment 67 of 89
# Param = 5.00000 - classifier Evaluation Experiment 68 of 89
# Param = 5.00000 - classifier Evaluation Experiment 69 of 89
# Param = 5.00000 - classifier Evaluation Experiment 70 of 89
# Param = 5.00000 - classifier Evaluation Experiment 71 of 89
# Param = 5.00000 - classifier Evaluation Experiment 72 of 89
# Param = 5.00000 - classifier Evaluation Experiment 73 of 89
# Param = 5.00000 - classifier Evaluation Experiment 74 of 89
# Param = 5.00000 - classifier Evaluation Experiment 75 of 89
# Param = 5.00000 - classifier Evaluation Experiment 76 of 89
# Param = 5.00000 - classifier Evaluation Experiment 77 of 89
# Param = 5.00000 - classifier Evaluation Experiment 78 of 89
# Param = 5.00000 - classifier Evaluation Experiment 79 of 89
# Param = 5.00000 - classifier Evaluation Experiment 80 of 89
# Param = 5.00000 - classifier Evaluation Experiment 81 of 89
# Param = 5.00000 - classifier Evaluation Experiment 82 of 89
# Param = 5.00000 - classifier Evaluation Experiment 83 of 89
# Param = 5.00000 - classifier Evaluation Experiment 84 of 89
# Param = 5.00000 - classifier Evaluation Experiment 85 of 89
# Param = 5.00000 - classifier Evaluation Experiment 86 of 89
# Param = 5.00000 - classifier Evaluation Experiment 87 of 89
# Param = 5.00000 - classifier Evaluation Experiment 88 of 89
# Param = 5.00000 - classifier Evaluation Experiment 89 of 89
# Param = 10.00000 - classifier Evaluation Experiment 1 of 89
# Param = 10.00000 - classifier Evaluation Experiment 2 of 89
# Param = 10.00000 - classifier Evaluation Experiment 3 of 89
# Param = 10.00000 - classifier Evaluation Experiment 4 of 89
# Param = 10.00000 - classifier Evaluation Experiment 5 of 89
# Param = 10.00000 - classifier Evaluation Experiment 6 of 89
# Param = 10.00000 - classifier Evaluation Experiment 7 of 89
# Param = 10.00000 - classifier Evaluation Experiment 8 of 89
# Param = 10.00000 - classifier Evaluation Experiment 9 of 89
# Param = 10.00000 - classifier Evaluation Experiment 10 of 89
# Param = 10.00000 - classifier Evaluation Experiment 11 of 89
# Param = 10.00000 - classifier Evaluation Experiment 12 of 89
# Param = 10.00000 - classifier Evaluation Experiment 13 of 89
# Param = 10.00000 - classifier Evaluation Experiment 14 of 89
# Param = 10.00000 - classifier Evaluation Experiment 15 of 89
# Param = 10.00000 - classifier Evaluation Experiment 16 of 89
# Param = 10.00000 - classifier Evaluation Experiment 17 of 89
# Param = 10.00000 - classifier Evaluation Experiment 18 of 89
# Param = 10.00000 - classifier Evaluation Experiment 19 of 89
# Param = 10.00000 - classifier Evaluation Experiment 20 of 89
# Param = 10.00000 - classifier Evaluation Experiment 21 of 89
# Param = 10.00000 - classifier Evaluation Experiment 22 of 89
# Param = 10.00000 - classifier Evaluation Experiment 23 of 89
# Param = 10.00000 - classifier Evaluation Experiment 24 of 89
# Param = 10.00000 - classifier Evaluation Experiment 25 of 89
# Param = 10.00000 - classifier Evaluation Experiment 26 of 89
# Param = 10.00000 - classifier Evaluation Experiment 27 of 89
# Param = 10.00000 - classifier Evaluation Experiment 28 of 89
# Param = 10.00000 - classifier Evaluation Experiment 29 of 89
# Param = 10.00000 - classifier Evaluation Experiment 30 of 89
# Param = 10.00000 - classifier Evaluation Experiment 31 of 89
# Param = 10.00000 - classifier Evaluation Experiment 32 of 89
# Param = 10.00000 - classifier Evaluation Experiment 33 of 89
# Param = 10.00000 - classifier Evaluation Experiment 34 of 89
# Param = 10.00000 - classifier Evaluation Experiment 35 of 89
# Param = 10.00000 - classifier Evaluation Experiment 36 of 89
# Param = 10.00000 - classifier Evaluation Experiment 37 of 89
# Param = 10.00000 - classifier Evaluation Experiment 38 of 89
# Param = 10.00000 - classifier Evaluation Experiment 39 of 89
# Param = 10.00000 - classifier Evaluation Experiment 40 of 89
# Param = 10.00000 - classifier Evaluation Experiment 41 of 89
# Param = 10.00000 - classifier Evaluation Experiment 42 of 89
# Param = 10.00000 - classifier Evaluation Experiment 43 of 89
# Param = 10.00000 - classifier Evaluation Experiment 44 of 89
# Param = 10.00000 - classifier Evaluation Experiment 45 of 89
# Param = 10.00000 - classifier Evaluation Experiment 46 of 89
# Param = 10.00000 - classifier Evaluation Experiment 47 of 89
# Param = 10.00000 - classifier Evaluation Experiment 48 of 89
# Param = 10.00000 - classifier Evaluation Experiment 49 of 89
# Param = 10.00000 - classifier Evaluation Experiment 50 of 89
# Param = 10.00000 - classifier Evaluation Experiment 51 of 89
# Param = 10.00000 - classifier Evaluation Experiment 52 of 89
# Param = 10.00000 - classifier Evaluation Experiment 53 of 89
# Param = 10.00000 - classifier Evaluation Experiment 54 of 89
# Param = 10.00000 - classifier Evaluation Experiment 55 of 89
# Param = 10.00000 - classifier Evaluation Experiment 56 of 89
# Param = 10.00000 - classifier Evaluation Experiment 57 of 89
# Param = 10.00000 - classifier Evaluation Experiment 58 of 89
# Param = 10.00000 - classifier Evaluation Experiment 59 of 89
# Param = 10.00000 - classifier Evaluation Experiment 60 of 89
# Param = 10.00000 - classifier Evaluation Experiment 61 of 89
# Param = 10.00000 - classifier Evaluation Experiment 62 of 89
# Param = 10.00000 - classifier Evaluation Experiment 63 of 89
# Param = 10.00000 - classifier Evaluation Experiment 64 of 89
# Param = 10.00000 - classifier Evaluation Experiment 65 of 89
# Param = 10.00000 - classifier Evaluation Experiment 66 of 89
# Param = 10.00000 - classifier Evaluation Experiment 67 of 89
# Param = 10.00000 - classifier Evaluation Experiment 68 of 89
# Param = 10.00000 - classifier Evaluation Experiment 69 of 89
# Param = 10.00000 - classifier Evaluation Experiment 70 of 89
# Param = 10.00000 - classifier Evaluation Experiment 71 of 89
# Param = 10.00000 - classifier Evaluation Experiment 72 of 89
# Param = 10.00000 - classifier Evaluation Experiment 73 of 89
# Param = 10.00000 - classifier Evaluation Experiment 74 of 89
# Param = 10.00000 - classifier Evaluation Experiment 75 of 89
# Param = 10.00000 - classifier Evaluation Experiment 76 of 89
# Param = 10.00000 - classifier Evaluation Experiment 77 of 89
# Param = 10.00000 - classifier Evaluation Experiment 78 of 89
# Param = 10.00000 - classifier Evaluation Experiment 79 of 89
# Param = 10.00000 - classifier Evaluation Experiment 80 of 89
# Param = 10.00000 - classifier Evaluation Experiment 81 of 89
# Param = 10.00000 - classifier Evaluation Experiment 82 of 89
# Param = 10.00000 - classifier Evaluation Experiment 83 of 89
# Param = 10.00000 - classifier Evaluation Experiment 84 of 89
# Param = 10.00000 - classifier Evaluation Experiment 85 of 89
# Param = 10.00000 - classifier Evaluation Experiment 86 of 89
# Param = 10.00000 - classifier Evaluation Experiment 87 of 89
# Param = 10.00000 - classifier Evaluation Experiment 88 of 89
# Param = 10.00000 - classifier Evaluation Experiment 89 of 89
# Param = 20.00000 - classifier Evaluation Experiment 1 of 89
# Param = 20.00000 - classifier Evaluation Experiment 2 of 89
# Param = 20.00000 - classifier Evaluation Experiment 3 of 89
# Param = 20.00000 - classifier Evaluation Experiment 4 of 89
# Param = 20.00000 - classifier Evaluation Experiment 5 of 89
# Param = 20.00000 - classifier Evaluation Experiment 6 of 89
# Param = 20.00000 - classifier Evaluation Experiment 7 of 89
# Param = 20.00000 - classifier Evaluation Experiment 8 of 89
# Param = 20.00000 - classifier Evaluation Experiment 9 of 89
# Param = 20.00000 - classifier Evaluation Experiment 10 of 89
# Param = 20.00000 - classifier Evaluation Experiment 11 of 89
# Param = 20.00000 - classifier Evaluation Experiment 12 of 89
# Param = 20.00000 - classifier Evaluation Experiment 13 of 89
# Param = 20.00000 - classifier Evaluation Experiment 14 of 89
# Param = 20.00000 - classifier Evaluation Experiment 15 of 89
# Param = 20.00000 - classifier Evaluation Experiment 16 of 89
# Param = 20.00000 - classifier Evaluation Experiment 17 of 89
# Param = 20.00000 - classifier Evaluation Experiment 18 of 89
# Param = 20.00000 - classifier Evaluation Experiment 19 of 89
# Param = 20.00000 - classifier Evaluation Experiment 20 of 89
# Param = 20.00000 - classifier Evaluation Experiment 21 of 89
# Param = 20.00000 - classifier Evaluation Experiment 22 of 89
# Param = 20.00000 - classifier Evaluation Experiment 23 of 89
# Param = 20.00000 - classifier Evaluation Experiment 24 of 89
# Param = 20.00000 - classifier Evaluation Experiment 25 of 89
# Param = 20.00000 - classifier Evaluation Experiment 26 of 89
# Param = 20.00000 - classifier Evaluation Experiment 27 of 89
# Param = 20.00000 - classifier Evaluation Experiment 28 of 89
# Param = 20.00000 - classifier Evaluation Experiment 29 of 89
# Param = 20.00000 - classifier Evaluation Experiment 30 of 89
# Param = 20.00000 - classifier Evaluation Experiment 31 of 89
# Param = 20.00000 - classifier Evaluation Experiment 32 of 89
# Param = 20.00000 - classifier Evaluation Experiment 33 of 89
# Param = 20.00000 - classifier Evaluation Experiment 34 of 89
# Param = 20.00000 - classifier Evaluation Experiment 35 of 89
# Param = 20.00000 - classifier Evaluation Experiment 36 of 89
# Param = 20.00000 - classifier Evaluation Experiment 37 of 89
# Param = 20.00000 - classifier Evaluation Experiment 38 of 89
# Param = 20.00000 - classifier Evaluation Experiment 39 of 89
# Param = 20.00000 - classifier Evaluation Experiment 40 of 89
# Param = 20.00000 - classifier Evaluation Experiment 41 of 89
# Param = 20.00000 - classifier Evaluation Experiment 42 of 89
# Param = 20.00000 - classifier Evaluation Experiment 43 of 89
# Param = 20.00000 - classifier Evaluation Experiment 44 of 89
# Param = 20.00000 - classifier Evaluation Experiment 45 of 89
# Param = 20.00000 - classifier Evaluation Experiment 46 of 89
# Param = 20.00000 - classifier Evaluation Experiment 47 of 89
# Param = 20.00000 - classifier Evaluation Experiment 48 of 89
# Param = 20.00000 - classifier Evaluation Experiment 49 of 89
# Param = 20.00000 - classifier Evaluation Experiment 50 of 89
# Param = 20.00000 - classifier Evaluation Experiment 51 of 89
# Param = 20.00000 - classifier Evaluation Experiment 52 of 89
# Param = 20.00000 - classifier Evaluation Experiment 53 of 89
# Param = 20.00000 - classifier Evaluation Experiment 54 of 89
# Param = 20.00000 - classifier Evaluation Experiment 55 of 89
# Param = 20.00000 - classifier Evaluation Experiment 56 of 89
# Param = 20.00000 - classifier Evaluation Experiment 57 of 89
# Param = 20.00000 - classifier Evaluation Experiment 58 of 89
# Param = 20.00000 - classifier Evaluation Experiment 59 of 89
# Param = 20.00000 - classifier Evaluation Experiment 60 of 89
# Param = 20.00000 - classifier Evaluation Experiment 61 of 89
# Param = 20.00000 - classifier Evaluation Experiment 62 of 89
# Param = 20.00000 - classifier Evaluation Experiment 63 of 89
# Param = 20.00000 - classifier Evaluation Experiment 64 of 89
# Param = 20.00000 - classifier Evaluation Experiment 65 of 89
# Param = 20.00000 - classifier Evaluation Experiment 66 of 89
# Param = 20.00000 - classifier Evaluation Experiment 67 of 89
# Param = 20.00000 - classifier Evaluation Experiment 68 of 89
# Param = 20.00000 - classifier Evaluation Experiment 69 of 89
# Param = 20.00000 - classifier Evaluation Experiment 70 of 89
# Param = 20.00000 - classifier Evaluation Experiment 71 of 89
# Param = 20.00000 - classifier Evaluation Experiment 72 of 89
# Param = 20.00000 - classifier Evaluation Experiment 73 of 89
# Param = 20.00000 - classifier Evaluation Experiment 74 of 89
# Param = 20.00000 - classifier Evaluation Experiment 75 of 89
# Param = 20.00000 - classifier Evaluation Experiment 76 of 89
# Param = 20.00000 - classifier Evaluation Experiment 77 of 89
# Param = 20.00000 - classifier Evaluation Experiment 78 of 89
# Param = 20.00000 - classifier Evaluation Experiment 79 of 89
# Param = 20.00000 - classifier Evaluation Experiment 80 of 89
# Param = 20.00000 - classifier Evaluation Experiment 81 of 89
# Param = 20.00000 - classifier Evaluation Experiment 82 of 89
# Param = 20.00000 - classifier Evaluation Experiment 83 of 89
# Param = 20.00000 - classifier Evaluation Experiment 84 of 89
# Param = 20.00000 - classifier Evaluation Experiment 85 of 89
# Param = 20.00000 - classifier Evaluation Experiment 86 of 89
# Param = 20.00000 - classifier Evaluation Experiment 87 of 89
# Param = 20.00000 - classifier Evaluation Experiment 88 of 89
# Param = 20.00000 - classifier Evaluation Experiment 89 of 89
# 		exhale			inhale		OVERALL
# 	C	PRE	REC	f1	PRE	REC	f1	ACC	f1
# 	0.001	89.9	62.1	73.5	72.6	93.5	81.7	78.4	77.6
# 	0.010	87.1	75.6	80.9	79.4	89.4	84.1	82.7	82.5
# 	0.500	84.9	79.4	82.1	80.9	86.1	83.4	82.8	82.7
# 	1.000	86.1	81.9	84.0	81.5	85.8	83.6	83.8	83.8	 best f1	 best Acc
# 	5.000	80.7	81.5	81.1	82.4	81.6	82.0	81.6	81.5
# 	10.000	82.5	81.6	82.1	81.9	82.8	82.3	82.2	82.2
# 	20.000	85.5	81.0	83.2	81.7	86.0	83.8	83.5	83.5
# Confusion Matrix:
# 	exh	inh
# exh	42.42	9.36
# inh	6.84	41.39
# Selected params: 1.00000

# %%
aT.file_classification("New Recording 4.wav", "svmSMtemp","svm")
# Out:
# (0.0, array([0.70988525, 0.29011475]), ['exhale', 'inhale'])

# %%
[Fs, x] = aIO.read_audio_file("New Recording 6.wav")
segments = aS.silence_removal(x, Fs, 0.020, 0.020, smooth_window = 1, weight = 0.3, plot = True)
segments
# Out:
# [[1.2, 2.52], [3.02, 4.0], [4.74, 6.38], [6.7, 8.22], [8.5, 10.5]]

# %%
oldAudio = AudioSegment.from_wav("New Recording 6.wav")
ct = 1
for segment in segments:
    newAudio = oldAudio[segment[0]*1000:segment[1]*1000]
    newAudio.export('test'+str(ct)+'.wav', format="wav")
    ct += 1

# %%
for i in range(1, 6):
    print(aT.file_classification("test" + str(i) + '.wav', "svmSMtemp","svm")[1])
# Out:
# [1.67933483e-05 9.99983207e-01]
# [0.02917732 0.97082268]
# [0.05597814 0.94402186]
# [0.11911105 0.88088895]
# [0.04863726 0.95136274]
